# %% [markdown]
# # Reading MAF Files with pyMut
#
# This notebook demonstrates how to read MAF files using the `read_maf` method from pyMut.
#
# ## Example: Loading TCGA LAML MAF file
#
# We'll load the `tcga_laml.maf.gz` file using assembly 37.

# %%
# Import the read_maf function
from pyMut.input import read_maf

# %%
# Load the MAF file
maf_path = "../../../src/pyMut/data/examples/MAF/tcga_laml.maf.gz"
py_mut = read_maf(path=maf_path, assembly="37")
# Out:
# 2025-08-01 01:44:49,103 | INFO | pyMut.input | Starting MAF reading: ../../../src/pyMut/data/examples/MAF/tcga_laml.maf.gz
# 2025-08-01 01:44:49,105 | INFO | pyMut.input | Loading from cache: ../../../src/pyMut/data/examples/MAF/.pymut_cache/tcga_laml.maf_8bfbda65c4b23428.parquet
# 2025-08-01 01:44:49,131 | INFO | pyMut.input | Cache loaded successfully in 0.03 seconds

# %%
# Display the first 5 rows
py_mut.head()
# Out:
#   CHROM        POS ID REF ALT QUAL FILTER TCGA-AB-2988 TCGA-AB-2869  \
# 0  chr9  100077177  .   T   C    .      .          T|T          T|T
# 1  chr9  100085148  .   G   A    .      .          G|G          G|G
# 2  chr9  100971322  .   A   C    .      .          A|A          A|A
# 3  chr9  104086335  .   C   T    .      .          C|C          C|C
# 4  chr9  104124840  .   G   A    .      .          G|A          G|G
#
#   TCGA-AB-3009  ... Strand Variant_Classification Variant_Type  \
# 0          T|T  ...      +                 SILENT          SNP
# 1          G|G  ...      +      MISSENSE_MUTATION          SNP
# 2          A|A  ...      +      MISSENSE_MUTATION          SNP
# 3          C|C  ...      +      MISSENSE_MUTATION          SNP
# 4          G|G  ...      +      MISSENSE_MUTATION          SNP
#
#   Reference_Allele Tumor_Seq_Allele1 Tumor_Seq_Allele2 Tumor_Sample_Barcode  \
# 0                T                 T                 C         TCGA-AB-2886
# ...
